# %%
from nltk.tokenize import RegexpTokenizer
from pdfminer.high_level import extract_text
from nltk.probability import FreqDist
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

# %%
# Extract the text from PDF file
text = extract_text('C:/Users/Mula Ram/Downloads/fwdinvoicesample/Sell Tax Invoice April,2021.pdf')
#pages = extract_pages('example.pdf')

# %%
print(text)

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_lg")
doc = nlp(text)
outputs = []
for word in doc.ents:
    outputs.append((word.text,word.label_))
outputs
# Out:
# [('P) Ltd', 'ORG'),
#  ('23', 'DATE'),
#  ('24', 'CARDINAL'),
#  ('AMR TECH PARK', 'ORG'),
#  ('Block 1', 'GPE'),
#  ('HOSUR', 'ORG'),
#  ('Bangalore', 'GPE'),
#  ('Urban Bangalore', 'ORG'),
#  ('560068', 'DATE'),
#  ('Karnataka', 'GPE'),
#  ('India', 'GPE'),
#  ('29', 'CARDINAL'),
#  ('GSTIN', 'ORG'),
#  ('29AAFCD5862R1ZR', 'CARDINAL'),
#  ('2022-01-20', 'DATE'),
#  ('DE81294237', 'CARDINAL'),
#  ('2022-01-20', 'DATE'),
#  ('07:31:20.0', 'DATE'),
#  ('CIN', 'ORG'),
#  ('NEWTOWN', 'GPE'),
#  ('North\n', 'GPE'),
#  ('24', 'CARDINAL'),
#  ('Parganas', 'GPE'),
#  ('West Bengal', 'GPE'),
#  ('700156', 'DATE'),
#  ('INDIA', 'GPE'),
#  ('West Bengal', 'GPE'),
#  ('19BODPK4644C1Z3', 'CARDINAL'),
#  ('8420673799', 'CARDINAL'),
#  ('INR', 'ORG'),
#  ('1', 'CARDINAL'),
#  ('997331', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('50000.00', 'CARDINAL'),
#  ('24000.00', 'CARDINAL'),
#  ('0.00', 'CARDINAL'),
#  ('0.00', 'CARDINAL'),
#  ('0.00', 'CARDINAL'),
#  ('4320.00', 'CARDINAL'),
# ...

# %%
import torch
from torch import nn

# Import external libraries
import argparse
import numpy as np
import opencv_wrapper as cvw
from skimage.filters import threshold_local
import json
import random
from string import ascii_uppercase, digits, punctuation
import colorama
import regex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [21], in <module>
# ----> 1 import torch
#       2 from torch import nn
#       4 # Import external libraries
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Create an instance of tokenizer using NLTK ResexpTokenizer
#
tokenizer = RegexpTokenizer('\w+')
#
# Tokenize the text read from PDF
#
tokens = tokenizer.tokenize(text)
#
# Find Frequency Distribution
#
freqdist = FreqDist(tokens)
#
# Find words whose length is greater than 5 and frequency greater than 20
#
long_frequent_words = [words for words in tokens if len(words) > 1 and freqdist[words] > 2]

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open('Shilpa_MS.pdf', 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

print(output_string.getvalue())
# Out:
#
#
#
#
#
#
# SHILPA M S
# #68, Mudugere, Haleupparahalli Post,
# Hosur Hobli, Gowribidanur Taluk,
# Chikkaballapura District
# Bangalore-561 210
# _____________________________________________________________
#
#       E-Mail: shilpams216@gmail.com
#       Contact No: +91 966 32 531 71
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CURRICULUM VITAE
#
#
# Career Objective
# To  enhance  my  skills  and  knowledge  by  integrating  them  with  a  challenging  work
# environment and associating myself with an organization having a global presence and
# tremendous  growth  opportunities  ,  thereby  providing  myself  as  an  asset  for  the
# organization.
#
# Academic Credentials
#
# QUALIFICATION   BOARD/UNIVERSITY
#
# YEAR
#
# PERCENTAGE
#
# MSW
#
# Bangalore University
#
# 2019
#
# 74%
#
# BA
#
# Acharya Womens College, Gouribidanur
#
# 2017
#
# 78%
#
# PUC
#
# Govt College, Gouribidanur
#
# 2014
#
# 64%
#
# SSLC
#
# Govt High School, Gouribidanur
#
# 2012
#
# 53%
#
# ...

# %%
s = str(output_string.getvalue())
print(s)
# Out:
#
#
#
#
#
#
# SHILPA M S
# #68, Mudugere, Haleupparahalli Post,
# Hosur Hobli, Gowribidanur Taluk,
# Chikkaballapura District
# Bangalore-561 210
# _____________________________________________________________
#
#       E-Mail: shilpams216@gmail.com
#       Contact No: +91 966 32 531 71
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CURRICULUM VITAE
#
#
# Career Objective
# To  enhance  my  skills  and  knowledge  by  integrating  them  with  a  challenging  work
# environment and associating myself with an organization having a global presence and
# tremendous  growth  opportunities  ,  thereby  providing  myself  as  an  asset  for  the
# organization.
#
# Academic Credentials
#
# QUALIFICATION   BOARD/UNIVERSITY
#
# YEAR
#
# PERCENTAGE
#
# MSW
#
# Bangalore University
#
# 2019
#
# 74%
#
# BA
#
# Acharya Womens College, Gouribidanur
#
# 2017
#
# 78%
#
# PUC
#
# Govt College, Gouribidanur
#
# 2014
#
# 64%
#
# SSLC
#
# Govt High School, Gouribidanur
#
# 2012
#
# 53%
#
# ...
