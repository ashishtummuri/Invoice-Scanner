# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd='C:/Users/Mula Ram/AppData/Local/Programs/Tesseract-OCR/tesseract.exe'

# %%
img = cv2.imread("C:/Users/Mula Ram/Downloads/fwdinvoicesample/img23.jpg")
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# GST INVOICE Original for Buyer
#
# BAIJNATH & SONS
#
# 43 HOUSE OF ALLOY STEEL
# 22, STRAND ROAD, KOLKATA - 1, Ph. : 2230-2777, 2243-4349
# m e-mail : baijnath.kolkata@gmail.com
# -- GSTIN : 19AADFB7015R2Z0, PAN No. : AADFB7015R
#
# Tansprtioss: EN TART
# [motedae' OG. OF. 2020 | Wicenimber” WB 19 @ OOFL
#
# eee we ee
#
# be uae os
#
# Fs ee
#
# Delivery/Cutting Charge
#
# id Exot, Ea ) TER5Io0
# <a roms:
#
# Bank Name : UNITED BANK OF INDIA | Bank Name : STATE BANK OF INDIA
# Branch ; Kolkata Branch 0084 Branch : N.S. Road
#
# Alc. No. : 0084050003621 Alc, No. : 11107795325
#
# IFSC : UTBIOCAL107 IFSC ; SBIN0000144
#
# Terms & Conditions : For BAIJNATH & SONS
#
# Goods once sold cannot be refunded without our approval. Our responsibility ceases ’ ow
#
# ‘once goods leave our godown. Please pay by RTGS, NEFT or A/c Payee Cheque only. é *
# Authorised Signatory
