# %%
os.chdir('C:/Users/Mula Ram/Downloads/CV')

# %%
import numpy as np
import pandas as pd
import string
import matplotlib.pyplot as plt 
import seaborn as sns
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

# %%
import os
import docx2txt
from pdfminer.high_level import extract_pages

def text_column(file):
    print(file)
    try:
        pages = docx2txt.process(file)
        #print(pages)
        
    except:
        output_string = StringIO()
        with open(file, 'rb') as in_file:
            parser = PDFParser(in_file)
            doc = PDFDocument(parser)
            rsrcmgr = PDFResourceManager()
            device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
            interpreter = PDFPageInterpreter(rsrcmgr, device)
            for page in PDFPage.create_pages(doc):
                interpreter.process_page(page)
                
            pages = str(output_string.getvalue())
            
            #print(pages)
    return pages    
lst = os.listdir('C:/Users/Mula Ram/Downloads/CV')
text_data = []
for file in lst:
    text = text_column(file)
    text_data.append(text)
text_data.shape
# Out:
# A.Dhananjayan.pdf
# A.Kannan.docx
# A.Praveen_Kumar.pdf
# Aarthi_Rai.pdf
# Abdul_Khayum.docx
# Abhijeet_Chourasia.docx
# Abhinav_Kumar.docx
# Abhisek_Panda.pdf
# Abhishek_Kumar_Shukla.docx
# ADAIKAPPAN_M.pdf
# Aditya_BR_Iyengar.pdf
# Aditya_Kapoor.pdf
# Aditya_Kislay.docx
# Aditya_S_Koparde.docx
# Aditya_Tripathy.pdf
# Aishwarya_soratur.docx
# Ajay_Anand.pdf
# Ajay_Kumar_Gupta.pdf
# Ajesh_M.pdf
# Akashlin_devakumar.pdf
# Akash_Sharma.pdf
# Akhil.docx
# Akhil.S.pdf
# AKHILESH_KUMAR.pdf
# AKHIL_PR.pdf
# Akilan_J.docx
# Akshay_Kumar.pdf
# Akshay_Maity.pdf
# AKSHAY_SHARMA.pdf
# ALAGIRI_S.pdf
# Alankrita_gupta.pdf
# Aljowilson.pdf
# Alka_Mishra.pdf
# ALOK_CHAND_V_R.pdf
# Alok_Ranjan.pdf
# Amaljith_Jayan.pdf
# Amal_mohan.pdf
# Aman_Rana.pdf
# Aman_Tandon.pdf
# Amaresh_sahoo.docx
# Amar_Sah.pdf
# Ambika_M.docx
# Amita_Rout (1).pdf
# Amita_Rout.pdf
# AMIT_KAUSHIK.docx
# Amit_Kumar_Patel.docx
# Amit_Kumar_Thakur.pdf
# AMRENDRA_PANDEY.docx
# Amrutha_Padeep.pdf
# ANANDA_H.pdf
# ANANDBABU_V.pdf
# ...

# %%
len(text_data)
# Out:
# 822

# %%
len(lst)
# Out:
# 822

# %%
corpus_resume = []
for text in text_data:
    # Convert all strings to lowercase
    text = text.lower()
    # Remove numbers
    text = re.sub(r'\d+','',text)
    text = re.sub(r'\n',' ',text)
    text = re.sub(r'\s+',' ',text)
    text = re.sub(r'\t',' ',text)
    # Remove punctuation
    text = text.translate(str.maketrans('','',string.punctuation))
    corpus_resume.append(text)
corpus_resumedata = corpus_resume
len(corpus_resumedata)
# Out:
# 822
